# %%
# Enabling the `widget` backend.
# This requires jupyter-matplotlib a.k.a. ipympl.
# ipympl can be install via pip or conda.
# %matplotlib widget
# aka import ipympl

import matplotlib.pyplot as plt
import numpy as np
import scipy.constants as ct
from scipy import integrate
from matplotlib import lines

# %%
n=10
l=0.1
r=0.01
nu=200
nn=200
a=4*r
b=2*l

# %%
def bobina(th):
    d=l/n
    ar=d/(2*np.pi)
    z=th
    x=r*np.cos(th/ar)
    y=r*np.sin(th/ar)
    p=np.array([x,y,z])
    return p
def B(x, y, z):
    V=integrate.quad(lambda th: k*-L/(np.sqrt((x-d)**2+(y+h)**2)), 0, dd)
    return V[0]

# %%
#BOBINA
th=np.linspace(0,l,num=nu)
pos=bobina(th)
yz=np.zeros(nu)
xz=r*np.cos(yz)
#CAMP
x = np.linspace(-a, a, nn)
y = np.linspace(-a, a, nn)
z = np.linspace(-b/2,b,nn)
X, Y, Z = np.meshgrid(x, y,z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(pos[0], pos[1], pos[2], 'gray')
ax.plot3D(xz,yz,th, 'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4ae0fc31211> in <module>
# ----> 1 fig = plt.figure()
#       2 ax = plt.axes(projection='3d')
#       3 ax.plot3D(pos[0], pos[1], pos[2], 'gray')
#       4 ax.plot3D(xz,yz,th, 'gray')
#
# NameError: name 'plt' is not defined
