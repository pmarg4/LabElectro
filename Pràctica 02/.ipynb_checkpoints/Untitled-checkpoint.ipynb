# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import os

if not os.path.exists("images"):
    os.mkdir("images")
import matplotlib.pyplot as plt


k=1.265569250534297
import scipy.constants as ct
from pylab import *

# %%
p1=pd.read_csv("p1.csv",sep=';',decimal=',')
p2=pd.read_csv("d2.csv",sep=';',decimal=',',na_filter=True,skip_blank_lines=True)
p3=pd.read_csv("d3.csv",sep=';',decimal=',',na_filter=True,skip_blank_lines=True)
p3=p3.dropna()
p2=p2.dropna()

# %% [markdown]
# Força cs corrent

# %%
p1.head()
# Out:
#       M        uM       I        uI  Unnamed: 4  Unnamed: 5
# 0   5.4  0.100000  2.6250  0.072572         NaN         NaN
# 1   9.4  0.100000  3.7500  0.067577         NaN         NaN
# 2  14.5  0.141421  4.3875  0.028137         NaN         NaN
# 3  20.4  0.100000  5.3350  0.045461         NaN         NaN
# 4  24.4  0.141421  5.9575  0.078262         NaN         NaN

# %%
M=p1["M"]/1000000
uM=p1["uM"]/1000000
I=p1["I"]
uI=p1["uI"]
F=M*ct.g
uF=np.sqrt((uM*ct.g)**2)

# %%
fig1=px.scatter(x=F,y=I**2,template='simple_white',trendline="ols",error_x=uF,error_y=uI)
   
fig1.update_xaxes(ticks="inside",
                mirror='ticks',showline=True,showgrid=True
                )
fig1.update_yaxes(ticks="inside",
                mirror='ticks',showline=True,showgrid=True

                )
fig1.update_layout(
xaxis_title=r'$F\text{ (N)}$',
yaxis_title=r'$I\text{ (A)}^2$'
)
fig1.write_image("P1.pdf",engine="kaleido")
results = px.get_trendline_results(fig1)
results = results.iloc[0]["px_fit_results"].summary()
print(results)
fit_results = px.get_trendline_results(fig1).px_fit_results.iloc[0]
fig1.show()
m=fit_results.params[1]
um=fit_results.bse[1]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.994
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     465.3
# Date:                Sun, 30 May 2021   Prob (F-statistic):           0.000218
# Time:                        22:31:38   Log-Likelihood:                -6.0594
# No. Observations:                   5   AIC:                             16.12
# Df Residuals:                       3   BIC:                             15.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7747      1.106     -0.700      0.534      -4.295       2.746
# x1          1.487e+05   6892.164     21.570      0.000    1.27e+05    1.71e+05
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.619
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.418
# Skew:                           0.099   Prob(JB):                        0.811
# Kurtosis:                       1.598   Cond. No.                     1.47e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /opt/conda/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning:
#
# omni_normtest is not valid with less than 8 observations; 5 samples were given.

# %% [markdown]
# Força vs separació

# %%
p2=p2.drop(0)
p2
# Out:
#       M        uM     G        uG
# 1   5.4  0.100000  13.5  1.224745
# 2   9.4  0.100000  23.5  2.345208
# 3  14.8  0.141421  39.5  3.674235
# 4  20.4  0.100000  58.5  2.345208
# 5  25.8  0.141421  74.0  1.732051

# %%
M1=p2["M"]/1000000
uM1=p2["uM"]/1000000
A1=p2["G"]
uA1=p2["uG"]
F1=M*ct.g
uF1=np.sqrt((uM1*ct.g)**2)

# %%
fig1=px.scatter(x=F1,y=A1,template='simple_white',trendline="ols",error_x=uF1,error_y=uA1)
   
fig1.update_xaxes(ticks="inside",
                mirror='ticks',showline=True,showgrid=True
                )
fig1.update_yaxes(ticks="inside",
                mirror='ticks',showline=True,showgrid=True

                )
fig1.update_layout(
xaxis_title=r'$F\text{ (N)}$',
yaxis_title=r'$\text{Angle (º)}$'
)
fig1.write_image("P1.pdf",engine="kaleido")
results1 = px.get_trendline_results(fig1)
results1= results1.iloc[0]["px_fit_results"].summary()
print(results1)
fit_results1 = px.get_trendline_results(fig1).px_fit_results.iloc[0]
fig1.show()
m1=fit_results1.params[1]
um1=fit_results1.bse[1]
k=m1
uk=um1
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     763.7
# Date:                Sun, 30 May 2021   Prob (F-statistic):           0.000104
# Time:                        22:31:48   Log-Likelihood:                -8.7291
# No. Observations:                   5   AIC:                             21.46
# Df Residuals:                       3   BIC:                             20.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -5.4126      1.887     -2.869      0.064     -11.417       0.592
# x1          3.249e+05   1.18e+04     27.634      0.000    2.87e+05    3.62e+05
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.584
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.826
# Skew:                           0.397   Prob(JB):                        0.662
# Kurtosis:                       1.174   Cond. No.                     1.47e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /opt/conda/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning:
#
# omni_normtest is not valid with less than 8 observations; 5 samples were given.

# %%
p3=pd.read_csv("d3.csv",sep=';',decimal=',',na_filter=True,skip_blank_lines=True)
p3=p3.dropna()
p3=p3.drop(4)
p3
# Out:
#     V  u   D  uD
# 0  10  1  55   1
# 1   8  1  57   1
# 2   6  1  73   1
# 3   4  1  98   1

# %%
V=p3["V"]/1000
uV=p3["u"]/1000
A=p3["D"]
uA=p3["uD"]

D1=1/V
# D1=V
uD1=np.sqrt(uV**2*(1/V**2)**2)
uF=np.sqrt((uA*k)**2+(uk*A)**2)


F=A*k
k
# Out:
# 324854.60142466036

# %%
fig1=px.scatter(x=D1,y=F,template='simple_white',trendline="ols",error_x=uD1,error_y=uF)
   
fig1.update_xaxes(ticks="inside",
                mirror='ticks',showline=True,showgrid=True
                )
fig1.update_yaxes(ticks="inside",
                mirror='ticks',showline=True,showgrid=True

                )
fig1.update_layout(
xaxis_title=r'$1/r\text{ (m)}$',
yaxis_title=r'$\text{Força (N)}$'
)
fig1.write_image("P1.pdf",engine="kaleido")
results = px.get_trendline_results(fig1)
results = results.iloc[0]["px_fit_results"].summary()
print(results)
fit_results = px.get_trendline_results(fig1).px_fit_results.iloc[0]
fig1.show()
m=fit_results.params[1]
um=fit_results.bse[1]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     149.1
# Date:                Sun, 30 May 2021   Prob (F-statistic):            0.00664
# Time:                        22:33:45   Log-Likelihood:                -59.173
# No. Observations:                   4   AIC:                             122.3
# Df Residuals:                       2   BIC:                             121.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.337e+06   1.36e+06      5.395      0.033    1.49e+06    1.32e+07
# x1          9.753e+04   7988.981     12.209      0.007    6.32e+04    1.32e+05
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.709
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.335
# Skew:                          -0.532   Prob(JB):                        0.846
# Kurtosis:                       2.064   Cond. No.                         509.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /opt/conda/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning:
#
# omni_normtest is not valid with less than 8 observations; 4 samples were given.

# %%
I=5.39
L=1/100
mu0=m*2*np.pi/(I**2*L)
mu0
# Out:
# 0.00021880370008904796

# %%
k
# Out:
# 0.3248546014246604
